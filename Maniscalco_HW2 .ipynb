# %% [markdown]
# #**HW 2: Optimize and train Deep Models**
#
# In this homework, we will explore how to develop a simple Deep Neural Network for image classification. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well know problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.

# %% [markdown]
# ## Exercise 2.1: Image Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layer Neural Network to perfrom image classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import time

#Set the log level in order to hide the unuseful warnings
import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)

# %% [markdown]
# ### Load Data: Fashion MNIST dataset
#
# We will use the Fashion MNIST dataset, a dataset of Zalando's articles. Each sample is a 28x28 pixels grayscale image, associated with a label from 10 classes:
#
# class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
#
# Each pixel intensity is represented by a uint8 (byte) from 0 to 255.
# We will divide the dataset in training, testing and validation set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of deep network.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = (
    fashion_mnist.load_data()) #The dataset is already divede in test and training...

#We extract the first 5000 samples of the training set, to use them as the validation set
X_valid, X_train = X_train_full[:5000], X_train_full[5000:] 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.show()

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (keras.models.Sequential) and add four layers to it by calling its add() method:
#
#
# *  we start with a Flatten layer (keras.layers.Flatten) to convert each 28x28 image to a single row of 784 pixel values. Since it is the first layer in your model, you should specify the input_shape argument, leaving out the batch size: [28, 28];
# *  a Dense layer (keras.layers.Dense) with 300 neurons, and the "relu" activation function;
# * another Dense layer with 100 neurons, also with the "relu" activation function;
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Call the model's summary() method to check if the model has been built correctly. Also, try using keras.utils.plot_model() to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_40 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_187 (Dense)            (None, 300)               235500
# _________________________________________________________________
# dense_188 (Dense)            (None, 100)               30100
# _________________________________________________________________
# dense_189 (Dense)            (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_mnist_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (?), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its compile() method to specify the loss function and the optimizer to use.
#
# The conventional way is to have the target outputs to match the output shape. In this case that would mean to convert the targets to the one-hot encoded array to match with the output shape.
# However, with the help of the sparse_categorical_crossentropy loss function, we can skip that step and keep the integers as targets.
#
#  In this case, we want to use the "sparse_categorical_crossentropy" loss, and the SGD optimizer (stochastic gradient descent).
#
#
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify metrics=["accuracy"].

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its fit() method, passing to it the input features (X_train) and the target classes (y_train). Set the number of epoch to 20.
# In order to validate our model we will also pass the validation data by setting validation_data=(X_valid, y_valid). Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the fit() method will return a History object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/20
# 55000/55000 [==============================] - 17s 305us/sample - loss: 2.5792 - accuracy: 0.6932 - val_loss: 0.7132 - val_accuracy: 0.7568
# Epoch 2/20
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.6434 - accuracy: 0.7583 - val_loss: 0.6256 - val_accuracy: 0.7792
# Epoch 3/20
# 55000/55000 [==============================] - 15s 276us/sample - loss: 0.5770 - accuracy: 0.7768 - val_loss: 0.6218 - val_accuracy: 0.7910
# Epoch 4/20
# 55000/55000 [==============================] - 15s 278us/sample - loss: 0.5364 - accuracy: 0.7922 - val_loss: 0.5994 - val_accuracy: 0.7944
# Epoch 5/20
# 55000/55000 [==============================] - 15s 278us/sample - loss: 0.5073 - accuracy: 0.8072 - val_loss: 0.5450 - val_accuracy: 0.8216
# Epoch 6/20
# 55000/55000 [==============================] - 15s 279us/sample - loss: 0.4772 - accuracy: 0.8221 - val_loss: 0.5339 - val_accuracy: 0.8250
# Epoch 7/20
# 55000/55000 [==============================] - 15s 280us/sample - loss: 0.4532 - accuracy: 0.8330 - val_loss: 0.5621 - val_accuracy: 0.8168
# Epoch 8/20
# 55000/55000 [==============================] - 15s 281us/sample - loss: 0.4343 - accuracy: 0.8394 - val_loss: 0.4942 - val_accuracy: 0.8306
# Epoch 9/20
# 55000/55000 [==============================] - 16s 282us/sample - loss: 0.4171 - accuracy: 0.8444 - val_loss: 0.4788 - val_accuracy: 0.8400
# Epoch 10/20
# 55000/55000 [==============================] - 15s 281us/sample - loss: 0.4068 - accuracy: 0.8478 - val_loss: 0.4859 - val_accuracy: 0.8344
# Epoch 11/20
# 55000/55000 [==============================] - 15s 282us/sample - loss: 0.3962 - accuracy: 0.8522 - val_loss: 0.4663 - val_accuracy: 0.8450
# Epoch 12/20
# 55000/55000 [==============================] - 16s 282us/sample - loss: 0.3863 - accuracy: 0.8561 - val_loss: 0.4884 - val_accuracy: 0.8350
# Epoch 13/20
# 55000/55000 [==============================] - 16s 283us/sample - loss: 0.3776 - accuracy: 0.8601 - val_loss: 0.4700 - val_accuracy: 0.8492
# Epoch 14/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3706 - accuracy: 0.8617 - val_loss: 0.4875 - val_accuracy: 0.8416
# Epoch 15/20
# 55000/55000 [==============================] - 16s 283us/sample - loss: 0.3635 - accuracy: 0.8638 - val_loss: 0.4477 - val_accuracy: 0.8524
# Epoch 16/20
# 55000/55000 [==============================] - 16s 283us/sample - loss: 0.3574 - accuracy: 0.8675 - val_loss: 0.4566 - val_accuracy: 0.8530
# Epoch 17/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3514 - accuracy: 0.8694 - val_loss: 0.4652 - val_accuracy: 0.8524
# Epoch 18/20
# 55000/55000 [==============================] - 16s 283us/sample - loss: 0.3463 - accuracy: 0.8707 - val_loss: 0.4488 - val_accuracy: 0.8584
# Epoch 19/20
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.3402 - accuracy: 0.8732 - val_loss: 0.4479 - val_accuracy: 0.8524
# Epoch 20/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3361 - accuracy: 0.8748 - val_loss: 0.4512 - val_accuracy: 0.8564

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the "plot_learning_curves" because we will reuse it in the next steps.

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 10000/10000 [==============================] - 2s 158us/sample - loss: 0.4808 - accuracy: 0.8388
# [0.4808244928956032, 0.8388]

# %% [markdown]
# ### Input normalization:
#
# When using Gradient Descent, it is usually a good idea to ensure that all the features have a similar scale. It's a common practice to scale your data inputs to have zero mean and unit variance. This is known as the standard scaler approach.
# Try to standardize the pixel values and see if this improves the performance of your neural network.

# %%
#To complete: define X_train_scaled, X_valid_scaled and X_test_scaled, the sets 
#that contain the normalized inputs.
#Hint: For each feature (pixel intensity), you must subtract the mean() of that 
#feature (across all instances, so use axis=0) and divide by its standard 
#deviation (std(), again axis=0)

X_train_scaled = (X_train - np.mean(X_train, axis=0))/np.std(X_train, axis=0)
X_valid_scaled = (X_valid - np.mean(X_valid, axis=0))/np.std(X_valid, axis=0)
X_test_scaled = (X_test - np.mean(X_test, axis=0))/np.std(X_test, axis=0)

#Make sure you compute the means and standard deviations on the training set,
#and use these statistics to scale the training set, the validation set and the
# test set

#Alternatively, you can use Scikit-Learn's StandardScaler...

# %% [markdown]
# Let's define the model in order to re-initialize the weights and then train it by using the normalize data.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

history = model.fit(X_train_scaled, y_train, epochs=20,
                    validation_data=(X_valid_scaled, y_valid))
print("Model Evaluation")
model.evaluate(X_test_scaled, y_test)
plot_learning_curves(history)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/20
# 55000/55000 [==============================] - 16s 290us/sample - loss: 0.9394 - accuracy: 0.6954 - val_loss: 0.6244 - val_accuracy: 0.7872
# Epoch 2/20
# 55000/55000 [==============================] - 15s 278us/sample - loss: 0.5797 - accuracy: 0.7991 - val_loss: 0.5243 - val_accuracy: 0.8148
# Epoch 3/20
# 55000/55000 [==============================] - 15s 278us/sample - loss: 0.5079 - accuracy: 0.8220 - val_loss: 0.4811 - val_accuracy: 0.8314
# Epoch 4/20
# 55000/55000 [==============================] - 16s 283us/sample - loss: 0.4694 - accuracy: 0.8336 - val_loss: 0.4541 - val_accuracy: 0.8388
# Epoch 5/20
# 55000/55000 [==============================] - 16s 282us/sample - loss: 0.4438 - accuracy: 0.8436 - val_loss: 0.4351 - val_accuracy: 0.8452
# Epoch 6/20
# 55000/55000 [==============================] - 16s 282us/sample - loss: 0.4248 - accuracy: 0.8503 - val_loss: 0.4220 - val_accuracy: 0.8522
# Epoch 7/20
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.4098 - accuracy: 0.8556 - val_loss: 0.4098 - val_accuracy: 0.8568
# Epoch 8/20
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.3974 - accuracy: 0.8601 - val_loss: 0.4014 - val_accuracy: 0.8588
# Epoch 9/20
# 55000/55000 [==============================] - 16s 286us/sample - loss: 0.3867 - accuracy: 0.8645 - val_loss: 0.3935 - val_accuracy: 0.8606
# Epoch 10/20
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.3775 - accuracy: 0.8671 - val_loss: 0.3874 - val_accuracy: 0.8636
# Epoch 11/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3692 - accuracy: 0.8704 - val_loss: 0.3817 - val_accuracy: 0.8664
# Epoch 12/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3620 - accuracy: 0.8733 - val_loss: 0.3768 - val_accuracy: 0.8692
# Epoch 13/20
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.3553 - accuracy: 0.8750 - val_loss: 0.3724 - val_accuracy: 0.8680
# Epoch 14/20
# 55000/55000 [==============================] - 16s 286us/sample - loss: 0.3491 - accuracy: 0.8765 - val_loss: 0.3690 - val_accuracy: 0.8710
# Epoch 15/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3435 - accuracy: 0.8789 - val_loss: 0.3630 - val_accuracy: 0.8728
# Epoch 16/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3382 - accuracy: 0.8815 - val_loss: 0.3608 - val_accuracy: 0.8740
# Epoch 17/20
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.3333 - accuracy: 0.8822 - val_loss: 0.3572 - val_accuracy: 0.8738
# Epoch 18/20
# 55000/55000 [==============================] - 16s 285us/sample - loss: 0.3283 - accuracy: 0.8835 - val_loss: 0.3555 - val_accuracy: 0.8740
# Epoch 19/20
# 55000/55000 [==============================] - 16s 286us/sample - loss: 0.3240 - accuracy: 0.8859 - val_loss: 0.3534 - val_accuracy: 0.8740
# Epoch 20/20
# 55000/55000 [==============================] - 16s 294us/sample - loss: 0.3199 - accuracy: 0.8863 - val_loss: 0.3504 - val_accuracy: 0.8754
# Model Evaluation
# 10000/10000 [==============================] - 2s 161us/sample - loss: 0.3811 - accuracy: 0.8649

# %% [markdown]
# Note that the validation curve is smoother than in the previous test and it is also more simlar to the training curve.

# %% [markdown]
# ## Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %%
#To complete: modify the previuos model in order to obtain  a new mdel that overfit the training data
#HINT: A model tends to overfit when too few training examples are available
X_train_small = X_train[:400]
y_train_small = y_train[:400]

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#To complete: Add layers
#HINT: A model tends to overfit  when the number of learnable parameters is very high compared to the number of training samples
#HINT: Is it possible to use different activation functions than ReLu

#model.add(keras.layers.Dense(10, activation="softmax"))
model.add(keras.layers.Dense(10, activation="softmax"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(10, activation="softmax"))


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-1)) #To complete:learning rate

#HINT: A model tends to overfit when the number of training epochs is high
history = model.fit(X_train_small, y_train_small, epochs=120,
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Train on 400 samples, validate on 5000 samples
# Epoch 1/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 2.3081 - val_loss: 2.2981
# Epoch 2/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3273 - val_loss: 2.3272
# Epoch 3/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3208 - val_loss: 2.3048
# Epoch 4/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3129 - val_loss: 2.3161
# Epoch 5/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3204 - val_loss: 2.3220
# Epoch 6/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3098 - val_loss: 2.3251
# Epoch 7/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3158 - val_loss: 2.3221
# Epoch 8/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3178 - val_loss: 2.3094
# Epoch 9/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3120 - val_loss: 2.3128
# Epoch 10/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3072 - val_loss: 2.3191
# Epoch 11/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3132 - val_loss: 2.3143
# Epoch 12/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3145 - val_loss: 2.3222
# Epoch 13/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3125 - val_loss: 2.3322
# Epoch 14/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3103 - val_loss: 2.3276
# Epoch 15/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3094 - val_loss: 2.3158
# Epoch 16/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3103 - val_loss: 2.3161
# Epoch 17/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3115 - val_loss: 2.3160
# Epoch 18/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3105 - val_loss: 2.3082
# Epoch 19/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3123 - val_loss: 2.3132
# Epoch 20/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3081 - val_loss: 2.3126
# Epoch 21/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3134 - val_loss: 2.3104
# Epoch 22/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3108 - val_loss: 2.3105
# Epoch 23/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3086 - val_loss: 2.3115
# Epoch 24/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3085 - val_loss: 2.3170
# Epoch 25/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3104 - val_loss: 2.3130
# Epoch 26/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3090 - val_loss: 2.3112
# Epoch 27/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3063 - val_loss: 2.3146
# Epoch 28/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3104 - val_loss: 2.3174
# Epoch 29/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3112 - val_loss: 2.3162
# Epoch 30/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3081 - val_loss: 2.3202
# Epoch 31/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3075 - val_loss: 2.3128
# Epoch 32/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3051 - val_loss: 2.3124
# Epoch 33/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3086 - val_loss: 2.3142
# Epoch 34/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3063 - val_loss: 2.3131
# Epoch 35/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3052 - val_loss: 2.3131
# Epoch 36/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3093 - val_loss: 2.3128
# Epoch 37/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3052 - val_loss: 2.3132
# Epoch 38/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3038 - val_loss: 2.3109
# Epoch 39/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3057 - val_loss: 2.3109
# Epoch 40/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3082 - val_loss: 2.3095
# Epoch 41/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3053 - val_loss: 2.3101
# Epoch 42/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3056 - val_loss: 2.3102
# Epoch 43/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3058 - val_loss: 2.3099
# Epoch 44/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3062 - val_loss: 2.3118
# Epoch 45/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3052 - val_loss: 2.3152
# Epoch 46/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3047 - val_loss: 2.3130
# Epoch 47/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3047 - val_loss: 2.3153
# Epoch 48/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3063 - val_loss: 2.3150
# Epoch 49/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3065 - val_loss: 2.3123
# Epoch 50/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3073 - val_loss: 2.3103
# Epoch 51/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3061 - val_loss: 2.3117
# Epoch 52/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3049 - val_loss: 2.3119
# Epoch 53/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3042 - val_loss: 2.3110
# Epoch 54/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3053 - val_loss: 2.3117
# Epoch 55/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3065 - val_loss: 2.3140
# Epoch 56/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3043 - val_loss: 2.3156
# Epoch 57/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3028 - val_loss: 2.3102
# Epoch 58/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3052 - val_loss: 2.3129
# Epoch 59/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3060 - val_loss: 2.3133
# Epoch 60/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3029 - val_loss: 2.3137
# Epoch 61/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3045 - val_loss: 2.3148
# Epoch 62/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3036 - val_loss: 2.3139
# Epoch 63/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3057 - val_loss: 2.3131
# Epoch 64/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3044 - val_loss: 2.3126
# Epoch 65/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3055 - val_loss: 2.3122
# Epoch 66/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3040 - val_loss: 2.3126
# Epoch 67/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3029 - val_loss: 2.3099
# Epoch 68/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3031 - val_loss: 2.3126
# Epoch 69/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3046 - val_loss: 2.3132
# Epoch 70/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3038 - val_loss: 2.3103
# Epoch 71/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3047 - val_loss: 2.3077
# Epoch 72/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3039 - val_loss: 2.3108
# Epoch 73/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3043 - val_loss: 2.3141
# Epoch 74/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3037 - val_loss: 2.3158
# Epoch 75/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3040 - val_loss: 2.3134
# Epoch 76/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3043 - val_loss: 2.3131
# Epoch 77/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3040 - val_loss: 2.3118
# Epoch 78/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3034 - val_loss: 2.3120
# Epoch 79/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3031 - val_loss: 2.3136
# Epoch 80/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3033 - val_loss: 2.3095
# Epoch 81/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3039 - val_loss: 2.3090
# Epoch 82/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3043 - val_loss: 2.3122
# Epoch 83/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3028 - val_loss: 2.3109
# Epoch 84/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3036 - val_loss: 2.3105
# Epoch 85/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3022 - val_loss: 2.3127
# Epoch 86/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3039 - val_loss: 2.3128
# Epoch 87/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3049 - val_loss: 2.3113
# Epoch 88/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3049 - val_loss: 2.3121
# Epoch 89/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3040 - val_loss: 2.3094
# Epoch 90/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3042 - val_loss: 2.3075
# Epoch 91/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3051 - val_loss: 2.3095
# Epoch 92/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3026 - val_loss: 2.3115
# Epoch 93/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3018 - val_loss: 2.3133
# Epoch 94/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3033 - val_loss: 2.3134
# Epoch 95/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3031 - val_loss: 2.3135
# Epoch 96/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3056 - val_loss: 2.3127
# Epoch 97/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3047 - val_loss: 2.3132
# Epoch 98/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3019 - val_loss: 2.3129
# Epoch 99/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3030 - val_loss: 2.3139
# Epoch 100/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3042 - val_loss: 2.3123
# Epoch 101/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3024 - val_loss: 2.3133
# Epoch 102/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3032 - val_loss: 2.3123
# Epoch 103/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3044 - val_loss: 2.3139
# Epoch 104/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3033 - val_loss: 2.3123
# Epoch 105/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3025 - val_loss: 2.3118
# Epoch 106/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3040 - val_loss: 2.3107
# Epoch 107/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3030 - val_loss: 2.3105
# Epoch 108/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3040 - val_loss: 2.3124
# Epoch 109/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3044 - val_loss: 2.3132
# Epoch 110/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3017 - val_loss: 2.3137
# Epoch 111/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3018 - val_loss: 2.3119
# Epoch 112/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3028 - val_loss: 2.3101
# Epoch 113/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3028 - val_loss: 2.3106
# Epoch 114/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3023 - val_loss: 2.3111
# Epoch 115/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3021 - val_loss: 2.3101
# Epoch 116/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3038 - val_loss: 2.3108
# Epoch 117/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3037 - val_loss: 2.3106
# Epoch 118/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3034 - val_loss: 2.3146
# Epoch 119/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3037 - val_loss: 2.3152
# Epoch 120/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3014 - val_loss: 2.3147
# Model Evaluation
# 10000/10000 [==============================] - 3s 328us/sample - loss: 2.3116
# 2.3115639003753663

# %% [markdown]
# Define the plot_learning_loss function and plot the loss and val_loss trends

# %%
def plot_learning_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_loss(history)

# %% [markdown]
# ### L1-norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfrom the L1-norm regularization

#To complete: insert the model that you previously define that overfit the 
#trainnig data, and add the L1-norm regularization. Use the proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. In general, a
#layer that exploits L1-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=To_complete, activation=To_complete,kernel_regularizer=tf.keras.regularizers.l1(To_complete))) 
model.add(keras.layers.Dense(10, activation="softmax"))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l1(0.001)))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l1(0.001)))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l1(0.001)))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l1(0.001)))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-1)) #To complete: learning rate

history = model.fit(X_train_small, y_train_small, epochs=120, #To complete: number of epochs
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Train on 400 samples, validate on 5000 samples
# Epoch 1/120
# 400/400 [==============================] - 3s 9ms/sample - loss: 31.2175 - val_loss: 30.6646
# Epoch 2/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 30.2562 - val_loss: 29.7267
# Epoch 3/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 29.2976 - val_loss: 28.7643
# Epoch 4/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 28.3579 - val_loss: 27.8461
# Epoch 5/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 27.4443 - val_loss: 26.9422
# Epoch 6/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 26.5359 - val_loss: 26.0528
# Epoch 7/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 25.6552 - val_loss: 25.1762
# Epoch 8/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 24.7869 - val_loss: 24.3116
# Epoch 9/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 23.9324 - val_loss: 23.4717
# Epoch 10/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 23.0964 - val_loss: 22.6479
# Epoch 11/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 22.2809 - val_loss: 21.8391
# Epoch 12/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 21.4802 - val_loss: 21.0490
# Epoch 13/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 20.6945 - val_loss: 20.2773
# Epoch 14/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 19.9241 - val_loss: 19.5165
# Epoch 15/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 19.1723 - val_loss: 18.7709
# Epoch 16/120
# 400/400 [==============================] - 3s 6ms/sample - loss: 18.4368 - val_loss: 18.0435
# Epoch 17/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 17.7174 - val_loss: 17.3333
# Epoch 18/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 17.0148 - val_loss: 16.6372
# Epoch 19/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 16.3285 - val_loss: 15.9614
# Epoch 20/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 15.6579 - val_loss: 15.3006
# Epoch 21/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 15.0063 - val_loss: 14.6560
# Epoch 22/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 14.3689 - val_loss: 14.0283
# Epoch 23/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 13.7472 - val_loss: 13.4175
# Epoch 24/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 13.1434 - val_loss: 12.8233
# Epoch 25/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 12.5561 - val_loss: 12.2450
# Epoch 26/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 11.9854 - val_loss: 11.6839
# Epoch 27/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 11.4306 - val_loss: 11.1394
# Epoch 28/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 10.8942 - val_loss: 10.6121
# Epoch 29/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 10.3732 - val_loss: 10.1000
# Epoch 30/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 9.8672 - val_loss: 9.6048
# Epoch 31/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 9.3781 - val_loss: 9.1240
# Epoch 32/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 8.9053 - val_loss: 8.6608
# Epoch 33/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 8.4505 - val_loss: 8.2141
# Epoch 34/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 8.0106 - val_loss: 7.7840
# Epoch 35/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 7.5873 - val_loss: 7.3699
# Epoch 36/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 7.1821 - val_loss: 6.9726
# Epoch 37/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 6.7909 - val_loss: 6.5923
# Epoch 38/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 6.4167 - val_loss: 6.2275
# Epoch 39/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 6.0609 - val_loss: 5.8796
# Epoch 40/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 5.7211 - val_loss: 5.5480
# Epoch 41/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 5.3962 - val_loss: 5.2329
# Epoch 42/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 5.0889 - val_loss: 4.9343
# Epoch 43/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 4.7971 - val_loss: 4.6518
# Epoch 44/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 4.5224 - val_loss: 4.3865
# Epoch 45/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 4.2635 - val_loss: 4.1374
# Epoch 46/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 4.0209 - val_loss: 3.9047
# Epoch 47/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7957 - val_loss: 3.6890
# Epoch 48/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5872 - val_loss: 3.4892
# Epoch 49/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3948 - val_loss: 3.3053
# Epoch 50/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2188 - val_loss: 3.1378
# Epoch 51/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.0588 - val_loss: 2.9870
# Epoch 52/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.9149 - val_loss: 2.8528
# Epoch 53/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.7881 - val_loss: 2.7348
# Epoch 54/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.6780 - val_loss: 2.6341
# Epoch 55/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.5841 - val_loss: 2.5498
# Epoch 56/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.5054 - val_loss: 2.4818
# Epoch 57/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.4436 - val_loss: 2.4281
# Epoch 58/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3997 - val_loss: 2.3932
# Epoch 59/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3719 - val_loss: 2.3747
# Epoch 60/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3592 - val_loss: 2.3703
# Epoch 61/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3576 - val_loss: 2.3692
# Epoch 62/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3553 - val_loss: 2.3669
# Epoch 63/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3542 - val_loss: 2.3652
# Epoch 64/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3524 - val_loss: 2.3634
# Epoch 65/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3515 - val_loss: 2.3620
# Epoch 66/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3494 - val_loss: 2.3606
# Epoch 67/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3478 - val_loss: 2.3581
# Epoch 68/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3466 - val_loss: 2.3578
# Epoch 69/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3464 - val_loss: 2.3570
# Epoch 70/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3447 - val_loss: 2.3552
# Epoch 71/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3439 - val_loss: 2.3532
# Epoch 72/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3428 - val_loss: 2.3531
# Epoch 73/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3423 - val_loss: 2.3535
# Epoch 74/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3413 - val_loss: 2.3542
# Epoch 75/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3407 - val_loss: 2.3528
# Epoch 76/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3403 - val_loss: 2.3520
# Epoch 77/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3395 - val_loss: 2.3510
# Epoch 78/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3392 - val_loss: 2.3504
# Epoch 79/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3387 - val_loss: 2.3504
# Epoch 80/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3380 - val_loss: 2.3486
# Epoch 81/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3381 - val_loss: 2.3480
# Epoch 82/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3383 - val_loss: 2.3490
# Epoch 83/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3375 - val_loss: 2.3486
# Epoch 84/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3379 - val_loss: 2.3488
# Epoch 85/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3373 - val_loss: 2.3494
# Epoch 86/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3381 - val_loss: 2.3495
# Epoch 87/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3386 - val_loss: 2.3487
# Epoch 88/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3381 - val_loss: 2.3491
# Epoch 89/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3381 - val_loss: 2.3480
# Epoch 90/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3381 - val_loss: 2.3471
# Epoch 91/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3385 - val_loss: 2.3474
# Epoch 92/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3374 - val_loss: 2.3486
# Epoch 93/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3371 - val_loss: 2.3491
# Epoch 94/120
# 400/400 [==============================] - 3s 6ms/sample - loss: 2.3378 - val_loss: 2.3495
# Epoch 95/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3376 - val_loss: 2.3496
# Epoch 96/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3388 - val_loss: 2.3498
# Epoch 97/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 2.3388 - val_loss: 2.3498
# Epoch 98/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3370 - val_loss: 2.3500
# Epoch 99/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3377 - val_loss: 2.3503
# Epoch 100/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3384 - val_loss: 2.3494
# Epoch 101/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3374 - val_loss: 2.3502
# Epoch 102/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3379 - val_loss: 2.3498
# Epoch 103/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3385 - val_loss: 2.3503
# Epoch 104/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3379 - val_loss: 2.3500
# Epoch 105/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3377 - val_loss: 2.3499
# Epoch 106/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3384 - val_loss: 2.3492
# Epoch 107/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3378 - val_loss: 2.3491
# Epoch 108/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3384 - val_loss: 2.3496
# Epoch 109/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3386 - val_loss: 2.3499
# Epoch 110/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3371 - val_loss: 2.3503
# Epoch 111/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3371 - val_loss: 2.3497
# Epoch 112/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3378 - val_loss: 2.3489
# Epoch 113/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3378 - val_loss: 2.3491
# Epoch 114/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3374 - val_loss: 2.3493
# Epoch 115/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3374 - val_loss: 2.3486
# Epoch 116/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3384 - val_loss: 2.3488
# Epoch 117/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3383 - val_loss: 2.3486
# Epoch 118/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3383 - val_loss: 2.3504
# Epoch 119/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3384 - val_loss: 2.3512
# Epoch 120/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3371 - val_loss: 2.3510
# Model Evaluation
# 10000/10000 [==============================] - 3s 315us/sample - loss: 2.3482

# %% [markdown]
# ### L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfrom the L2-norm regularization

#To complete: insert the model that you previously define that overfit the 
#trainnig data, and add the L2-norm regularization. Use the proper value for the
#alpha hyper-parameter,2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=To_complete, activation=To_complete,kernel_regularizer=tf.keras.regularizers.l1(To_complete))) 

model.add(keras.layers.Dense(10, activation="softmax"))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(keras.layers.Dense(500, activation="tanh",kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-1)) #To complete: learning rate

history = model.fit(X_train_small, y_train_small, epochs=120, #To complete: number of epochs
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Train on 400 samples, validate on 5000 samples
# Epoch 1/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 3.8277 - val_loss: 3.8201
# Epoch 2/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.8317 - val_loss: 3.8246
# Epoch 3/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.8170 - val_loss: 3.8019
# Epoch 4/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.8033 - val_loss: 3.8058
# Epoch 5/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.8025 - val_loss: 3.7996
# Epoch 6/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.7842 - val_loss: 3.7953
# Epoch 7/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.7832 - val_loss: 3.7812
# Epoch 8/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7756 - val_loss: 3.7656
# Epoch 9/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7637 - val_loss: 3.7610
# Epoch 10/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7520 - val_loss: 3.7578
# Epoch 11/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7496 - val_loss: 3.7472
# Epoch 12/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7420 - val_loss: 3.7472
# Epoch 13/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7339 - val_loss: 3.7459
# Epoch 14/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7240 - val_loss: 3.7332
# Epoch 15/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7167 - val_loss: 3.7200
# Epoch 16/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7095 - val_loss: 3.7106
# Epoch 17/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.7026 - val_loss: 3.7047
# Epoch 18/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6955 - val_loss: 3.6903
# Epoch 19/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.6886 - val_loss: 3.6857
# Epoch 20/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6783 - val_loss: 3.6794
# Epoch 21/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6749 - val_loss: 3.6710
# Epoch 22/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6658 - val_loss: 3.6638
# Epoch 23/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6565 - val_loss: 3.6570
# Epoch 24/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6499 - val_loss: 3.6519
# Epoch 25/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6439 - val_loss: 3.6440
# Epoch 26/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6363 - val_loss: 3.6363
# Epoch 27/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6270 - val_loss: 3.6317
# Epoch 28/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6232 - val_loss: 3.6263
# Epoch 29/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6170 - val_loss: 3.6193
# Epoch 30/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6078 - val_loss: 3.6161
# Epoch 31/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.6002 - val_loss: 3.6034
# Epoch 32/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5916 - val_loss: 3.5960
# Epoch 33/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5875 - val_loss: 3.5905
# Epoch 34/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.5788 - val_loss: 3.5831
# Epoch 35/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5716 - val_loss: 3.5768
# Epoch 36/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5681 - val_loss: 3.5703
# Epoch 37/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5583 - val_loss: 3.5650
# Epoch 38/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5505 - val_loss: 3.5562
# Epoch 39/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.5460 - val_loss: 3.5500
# Epoch 40/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5410 - val_loss: 3.5418
# Epoch 41/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5319 - val_loss: 3.5356
# Epoch 42/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5263 - val_loss: 3.5292
# Epoch 43/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5200 - val_loss: 3.5228
# Epoch 44/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5141 - val_loss: 3.5174
# Epoch 45/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5069 - val_loss: 3.5122
# Epoch 46/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.5002 - val_loss: 3.5057
# Epoch 47/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4939 - val_loss: 3.5014
# Epoch 48/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4890 - val_loss: 3.4947
# Epoch 49/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4829 - val_loss: 3.4881
# Epoch 50/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4773 - val_loss: 3.4801
# Epoch 51/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4706 - val_loss: 3.4741
# Epoch 52/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4632 - val_loss: 3.4682
# Epoch 53/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4571 - val_loss: 3.4620
# Epoch 54/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4518 - val_loss: 3.4564
# Epoch 55/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4466 - val_loss: 3.4522
# Epoch 56/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4389 - val_loss: 3.4474
# Epoch 57/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.4320 - val_loss: 3.4378
# Epoch 58/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4277 - val_loss: 3.4336
# Epoch 59/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4223 - val_loss: 3.4278
# Epoch 60/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.4144 - val_loss: 3.4217
# Epoch 61/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.4101 - val_loss: 3.4174
# Epoch 62/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.4033 - val_loss: 3.4108
# Epoch 63/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3988 - val_loss: 3.4050
# Epoch 64/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3924 - val_loss: 3.3990
# Epoch 65/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3876 - val_loss: 3.3932
# Epoch 66/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3809 - val_loss: 3.3880
# Epoch 67/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3747 - val_loss: 3.3796
# Epoch 68/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3688 - val_loss: 3.3759
# Epoch 69/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.3647 - val_loss: 3.3709
# Epoch 70/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3586 - val_loss: 3.3637
# Epoch 71/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3534 - val_loss: 3.3569
# Epoch 72/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3475 - val_loss: 3.3528
# Epoch 73/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3423 - val_loss: 3.3493
# Epoch 74/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3367 - val_loss: 3.3460
# Epoch 75/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3312 - val_loss: 3.3388
# Epoch 76/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3261 - val_loss: 3.3335
# Epoch 77/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3206 - val_loss: 3.3271
# Epoch 78/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3151 - val_loss: 3.3221
# Epoch 79/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3097 - val_loss: 3.3177
# Epoch 80/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.3041 - val_loss: 3.3096
# Epoch 81/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2995 - val_loss: 3.3043
# Epoch 82/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2945 - val_loss: 3.3007
# Epoch 83/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.2882 - val_loss: 3.2950
# Epoch 84/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2839 - val_loss: 3.2897
# Epoch 85/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2777 - val_loss: 3.2855
# Epoch 86/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.2739 - val_loss: 3.2809
# Epoch 87/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2695 - val_loss: 3.2749
# Epoch 88/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.2641 - val_loss: 3.2703
# Epoch 89/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2588 - val_loss: 3.2639
# Epoch 90/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2539 - val_loss: 3.2576
# Epoch 91/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2496 - val_loss: 3.2536
# Epoch 92/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2429 - val_loss: 3.2498
# Epoch 93/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2376 - val_loss: 3.2461
# Epoch 94/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2335 - val_loss: 3.2419
# Epoch 95/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2286 - val_loss: 3.2370
# Epoch 96/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2256 - val_loss: 3.2322
# Epoch 97/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2204 - val_loss: 3.2276
# Epoch 98/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.2133 - val_loss: 3.2226
# Epoch 99/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.2095 - val_loss: 3.2185
# Epoch 100/120
# 400/400 [==============================] - 2s 6ms/sample - loss: 3.2057 - val_loss: 3.2126
# Epoch 101/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1997 - val_loss: 3.2086
# Epoch 102/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.1956 - val_loss: 3.2034
# Epoch 103/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1916 - val_loss: 3.1997
# Epoch 104/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1863 - val_loss: 3.1947
# Epoch 105/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1813 - val_loss: 3.1897
# Epoch 106/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1777 - val_loss: 3.1842
# Epoch 107/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1725 - val_loss: 3.1798
# Epoch 108/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1687 - val_loss: 3.1761
# Epoch 109/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1641 - val_loss: 3.1719
# Epoch 110/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1579 - val_loss: 3.1676
# Epoch 111/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.1534 - val_loss: 3.1625
# Epoch 112/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.1498 - val_loss: 3.1571
# Epoch 113/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.1453 - val_loss: 3.1528
# Epoch 114/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.1407 - val_loss: 3.1486
# Epoch 115/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 3.1362 - val_loss: 3.1435
# Epoch 116/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1329 - val_loss: 3.1394
# Epoch 117/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1285 - val_loss: 3.1352
# Epoch 118/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1242 - val_loss: 3.1331
# Epoch 119/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1200 - val_loss: 3.1297
# Epoch 120/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 3.1142 - val_loss: 3.1254
# Model Evaluation
# 10000/10000 [==============================] - 3s 318us/sample - loss: 3.1225

# %% [markdown]
# ### Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (patience hyper-parameter), it stops the training phase.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

model.add(keras.layers.Dense(10, activation="softmax"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(500, activation="tanh"))
model.add(keras.layers.Dense(10, activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-1)) #To complete: learning rate

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the Eraly stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=20), #To complete: play with patience and find the value that prevents the model from overfitting
    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train_small, y_train_small, epochs=120, #To complete: number of epochs
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Train on 400 samples, validate on 5000 samples
# Epoch 1/120
# 400/400 [==============================] - 3s 7ms/sample - loss: 2.3184 - val_loss: 2.3000
# Epoch 2/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3120 - val_loss: 2.2466
# Epoch 3/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3171 - val_loss: 2.3039
# Epoch 4/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3124 - val_loss: 2.3136
# Epoch 5/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3228 - val_loss: 2.3077
# Epoch 6/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3099 - val_loss: 2.3036
# Epoch 7/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3182 - val_loss: 2.3126
# Epoch 8/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3185 - val_loss: 2.3041
# Epoch 9/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3132 - val_loss: 2.3023
# Epoch 10/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3075 - val_loss: 2.3041
# Epoch 11/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3146 - val_loss: 2.3085
# Epoch 12/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3151 - val_loss: 2.3092
# Epoch 13/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3113 - val_loss: 2.3176
# Epoch 14/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3116 - val_loss: 2.3066
# Epoch 15/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3104 - val_loss: 2.3016
# Epoch 16/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3115 - val_loss: 2.3030
# Epoch 17/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3119 - val_loss: 2.3025
# Epoch 18/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3113 - val_loss: 2.2976
# Epoch 19/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3121 - val_loss: 2.3013
# Epoch 20/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3082 - val_loss: 2.3010
# Epoch 21/120
# 400/400 [==============================] - 2s 4ms/sample - loss: 2.3138 - val_loss: 2.2958
# Epoch 22/120
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3118 - val_loss: 2.3003
# Model Evaluation
# 10000/10000 [==============================] - 4s 370us/sample - loss: 2.2444

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit. The aim of the model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learnign rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    keras.layers.Flatten(input_shape=[28, 28]),
                                    keras.layers.Dense(300, activation="relu"),
                                    keras.layers.Dense(10, activation="softmax")])

    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train_scaled, y_train,
                        validation_data=(X_valid_scaled, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 16s 287us/sample - loss: 1.8344 - accuracy: 0.3574 - val_loss: 1.2568 - val_accuracy: 0.5922
# Epoch 2/10
# 55000/55000 [==============================] - 15s 277us/sample - loss: 1.1050 - accuracy: 0.6410 - val_loss: 0.9798 - val_accuracy: 0.6798
# Epoch 3/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.9262 - accuracy: 0.6974 - val_loss: 0.8597 - val_accuracy: 0.7188
# Epoch 4/10
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.8338 - accuracy: 0.7239 - val_loss: 0.7881 - val_accuracy: 0.7408
# Epoch 5/10
# 55000/55000 [==============================] - 15s 277us/sample - loss: 0.7744 - accuracy: 0.7413 - val_loss: 0.7391 - val_accuracy: 0.7532
# Epoch 6/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.7317 - accuracy: 0.7547 - val_loss: 0.7029 - val_accuracy: 0.7658
# Epoch 7/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.6991 - accuracy: 0.7643 - val_loss: 0.6746 - val_accuracy: 0.7740
# Epoch 8/10
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.6729 - accuracy: 0.7731 - val_loss: 0.6515 - val_accuracy: 0.7784
# Epoch 9/10
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.6513 - accuracy: 0.7798 - val_loss: 0.6325 - val_accuracy: 0.7858
# Epoch 10/10
# 55000/55000 [==============================] - 15s 277us/sample - loss: 0.6331 - accuracy: 0.7857 - val_loss: 0.6163 - val_accuracy: 0.7914
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 16s 284us/sample - loss: 0.5160 - accuracy: 0.8212 - val_loss: 0.4093 - val_accuracy: 0.8570
# Epoch 2/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.3773 - accuracy: 0.8651 - val_loss: 0.3673 - val_accuracy: 0.8678
# Epoch 3/10
# 55000/55000 [==============================] - 15s 280us/sample - loss: 0.3411 - accuracy: 0.8793 - val_loss: 0.3579 - val_accuracy: 0.8762
# Epoch 4/10
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.3180 - accuracy: 0.8864 - val_loss: 0.3377 - val_accuracy: 0.8784
# Epoch 5/10
# 55000/55000 [==============================] - 15s 272us/sample - loss: 0.2989 - accuracy: 0.8929 - val_loss: 0.3313 - val_accuracy: 0.8822
# Epoch 6/10
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.2842 - accuracy: 0.8996 - val_loss: 0.3310 - val_accuracy: 0.8812
# Epoch 7/10
# 55000/55000 [==============================] - 15s 276us/sample - loss: 0.2708 - accuracy: 0.9041 - val_loss: 0.3213 - val_accuracy: 0.8872
# Epoch 8/10
# 55000/55000 [==============================] - 15s 273us/sample - loss: 0.2588 - accuracy: 0.9081 - val_loss: 0.3171 - val_accuracy: 0.8862
# Epoch 9/10
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.2483 - accuracy: 0.9109 - val_loss: 0.3156 - val_accuracy: 0.8942
# Epoch 10/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.2382 - accuracy: 0.9150 - val_loss: 0.3162 - val_accuracy: 0.8874
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 16s 287us/sample - loss: 0.4675 - accuracy: 0.8365 - val_loss: 0.3840 - val_accuracy: 0.8654
# Epoch 2/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.3484 - accuracy: 0.8740 - val_loss: 0.3643 - val_accuracy: 0.8712
# Epoch 3/10
# 55000/55000 [==============================] - 17s 307us/sample - loss: 0.3055 - accuracy: 0.8893 - val_loss: 0.3584 - val_accuracy: 0.8774
# Epoch 4/10
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.2718 - accuracy: 0.9006 - val_loss: 0.3579 - val_accuracy: 0.8780
# Epoch 5/10
# 55000/55000 [==============================] - 15s 274us/sample - loss: 0.2561 - accuracy: 0.9078 - val_loss: 0.3973 - val_accuracy: 0.8750
# Epoch 6/10
# 55000/55000 [==============================] - 15s 275us/sample - loss: 0.2342 - accuracy: 0.9148 - val_loss: 0.3953 - val_accuracy: 0.8800

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_curves(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# Note that the learning rate influence significantly the training phase. That behavior suggests that is crucial to validate the hyper-parameters to obtain good results.

# %% [markdown]
# ### GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use GridSearchCV method from scikit-learn.

# %% [markdown]
# Let's Create a build_model() function that takes two arguments, n_units and learning_rate, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time demends of the proces we will consider only this two hyper-paramters and a small 3 layer model.

# %%
def build_model(n_units=30, learning_rate=1e-3):

  #To complete:
  #HINT: the function has to build the model with 3 layers:
  #- a Flatten layer to convert each 28x28 image to a single row 
  #- a Danse layer composed of n_units and that exploits Relu activation function 
  #- the output layer that uses the softmax activation function
  #Then, has to be defined how the model will be compiled.
    
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=[28, 28]))
    model.add(keras.layers.Dense(n_units, activation="relu"))
    model.add(keras.layers.Dense(10, activation="softmax"))
    
    model.compile(loss="sparse_categorical_crossentropy",optimizer=keras.optimizers.SGD(lr=learning_rate),metrics=["accuracy"])
    
    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [30,50],# To_complete: insert a few (2 or 3) reasonable values  
    "learning_rate": [0.1,0.001]} # To_complete: insert a few (2 or 3) reasonable values
    #Check how much increase the time required to perform GRID search increasing
    #the number of the values for each hyper-parameter.

# %% [markdown]
# Use a sklearn.model_selection.GridSearchCV to search the hyperparameter space of your KerasRegressor

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train_scaled, y_train, epochs=10, #The number of epochs can be modified (check what happens by increasing it) 
                  validation_data=(X_valid_scaled, y_valid))
# Out:
# Train on 44000 samples, validate on 5000 samples
# Epoch 1/10
# 44000/44000 [==============================] - 7s 168us/sample - loss: 0.4909 - accuracy: 0.8248 - val_loss: 0.3936 - val_accuracy: 0.8618
# Epoch 2/10
# 44000/44000 [==============================] - 7s 154us/sample - loss: 0.3872 - accuracy: 0.8596 - val_loss: 0.4035 - val_accuracy: 0.8546
# Epoch 3/10
# 44000/44000 [==============================] - 7s 164us/sample - loss: 0.3532 - accuracy: 0.8705 - val_loss: 0.3807 - val_accuracy: 0.8716
# Epoch 4/10
# 44000/44000 [==============================] - 7s 168us/sample - loss: 0.3324 - accuracy: 0.8794 - val_loss: 0.3878 - val_accuracy: 0.8666
# Epoch 5/10
# 44000/44000 [==============================] - 7s 150us/sample - loss: 0.3172 - accuracy: 0.8836 - val_loss: 0.3915 - val_accuracy: 0.8660
# Epoch 6/10
# 44000/44000 [==============================] - 7s 153us/sample - loss: 0.3023 - accuracy: 0.8878 - val_loss: 0.3873 - val_accuracy: 0.8708
# Epoch 7/10
# 44000/44000 [==============================] - 7s 161us/sample - loss: 0.2912 - accuracy: 0.8933 - val_loss: 0.3948 - val_accuracy: 0.8654
# Epoch 8/10
# 44000/44000 [==============================] - 7s 154us/sample - loss: 0.2837 - accuracy: 0.8944 - val_loss: 0.4215 - val_accuracy: 0.8674
# Epoch 9/10
# 44000/44000 [==============================] - 7s 152us/sample - loss: 0.2765 - accuracy: 0.8986 - val_loss: 0.4582 - val_accuracy: 0.8530
# Epoch 10/10
# 44000/44000 [==============================] - 7s 151us/sample - loss: 0.2668 - accuracy: 0.9025 - val_loss: 0.4232 - val_accuracy: 0.8608
# 11000/11000 [==============================] - 1s 98us/sample - loss: 0.4170 - accuracy: 0.8619
# Train on 44000 samples, validate on 5000 samples
# Epoch 1/10
# 44000/44000 [==============================] - 8s
10
# 44000/44000 [==============================] - 7s 163us/sample - loss: 0.6798 - accuracy: 0.7677 - val_loss: 0.6218 - val_accuracy: 0.7876
# Epoch 3/10
# 44000/44000 [==============================] - 7s 164us/sample - loss: 0.5906 - accuracy: 0.7950 - val_loss: 0.5657 - val_accuracy: 0.8030
# Epoch 4/10
# 44000/44000 [==============================] - 7s 163us/sample - loss: 0.5445 - accuracy: 0.8106 - val_loss: 0.5310 - val_accuracy: 0.8130
# Epoch 5/10
# 44000/44000 [==============================] - 7s 163us/sample - loss: 0.5149 - accuracy: 0.8197 - val_loss: 0.5085 - val_accuracy: 0.8224
# Epoch 6/10
# 44000/44000 [==============================] - 7s 164us/sample - loss: 0.4937 - accuracy: 0.8264 - val_loss: 0.4928 - val_accuracy: 0.8270
# Epoch 7/10
# 44000/44000 [==============================] - 7s 164us/sample - loss: 0.4774 - accuracy: 0.8319 - val_loss: 0.4796 - val_accuracy: 0.8314
# Epoch 8/10
# 44000/44000 [==============================] - 7s 164us/sample - loss: 0.4641 - accuracy: 0.8363 - val_loss: 0.4685 - val_accuracy: 0.8346
# Epoch 9/10
# 44000/44000 [==============================] - 7s 163us/sample - loss: 0.4531 - accuracy: 0.8395 - val_loss: 0.4598 - val_accuracy: 0.8398
# Epoch 10/10
# 44000/44000 [==============================] - 7s 163us/sample - loss: 0.4437 - accuracy: 0.8436 - val_loss: 0.4529 - val_accuracy: 0.8388
# 11000/11000 [==============================] - 1s 99us/sample - loss: 0.4641 - accuracy: 0.8366
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 10s 178us/sample - loss: 0.4696 - accuracy: 0.8320 - val_loss: 0.3883 - val_accuracy: 0.8602
# Epoch 2/10
# 55000/55000 [==============================] - 9s 163us/sample - loss: 0.3640 - accuracy: 0.8673 - val_loss: 0.3639 - val_accuracy: 0.8692
# Epoch 3/10
# 55000/55000 [==============================] - 9s 164us/sample - loss: 0.3309 - accuracy: 0.8788 - val_loss: 0.3662 - val_accuracy: 0.8668
# Epoch 4/10
# 55000/55000 [==============================] - 9s 164us/sample - loss: 0.3109 - accuracy: 0.8867 - val_loss: 0.3560 - val_accuracy: 0.8782
# Epoch 5/10
# 55000/55000 [==============================] - 9s 164us/sample - loss: 0.2910 - accuracy: 0.8926 - val_loss: 0.3602 - val_accuracy: 0.8724
# Epoch 6/10
# 55000/55000 [==============================] - 9s 164us/sample - loss: 0.2783 - accuracy: 0.8975 - val_loss: 0.3830 - val_accuracy: 0.8730
# Epoch 7/10
# 55000/55000 [==============================] - 9s 162us/sample - loss: 0.2643 - accuracy: 0.9011 - val_loss: 0.4379 - val_accuracy: 0.8540
# Epoch 8/10
# 55000/55000 [==============================] - 9s 164us/sample - loss: 0.2572 - accuracy: 0.9051 - val_loss: 0.3477 - val_accuracy: 0.8840
# Epoch 9/10
# 55000/55000 [==============================] - 9s 164us/sample - loss: 0.2473 - accuracy: 0.9083 - val_loss: 0.3835 - val_accuracy: 0.8736
# Epoch 10/10
# 55000/55000 [==============================] - 9s 163us/sample - loss: 0.2414 - accuracy: 0.9110 - val_loss: 0.3759 - val_accuracy: 0.8760
# GridSearchCV(cv=None, error_score=nan,
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasRegressor object at 0x7ff4c3ad67f0>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.001], 'n_units': [30, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test_scaled, y_test)
# Out:
# {'learning_rate': 0.1, 'n_units': 50}
# 10000/10000 [==============================] - 1s 105us/sample - loss: 0.4109 - accuracy: 0.8684
# [0.4108629444122314, 0.8684]
